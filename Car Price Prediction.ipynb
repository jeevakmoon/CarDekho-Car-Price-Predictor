# %%
import pandas as pd

# %%
car = pd.read_csv('car data.csv')

# %%
car.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Diesel      Dealer       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   company        301 non-null    object
#  2   Year           301 non-null    int64
#  3   Selling_Price  301 non-null    float64
#  4   Present_Price  301 non-null    float64
#  5   Kms_Driven     301 non-null    int64
#  6   Fuel_Type      301 non-null    object
#  7   Seller_Type    301 non-null    object
#  8   Transmission   301 non-null    object
#  9   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 23.6+ KB

# %%
car.shape
# Out:
# (301, 10)

# %%
 car['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007], dtype=int64)

# %%
 car['Selling_Price'].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
# ...

# %%
 car['Present_Price'].unique()
# Out:
# array([ 5.59 ,  9.54 ,  9.85 ,  4.15 ,  6.87 ,  9.83 ,  8.12 ,  8.61 ,
#         8.89 ,  8.92 ,  3.6  , 10.38 ,  9.94 ,  7.71 ,  7.21 , 10.79 ,
#         5.09 ,  7.98 ,  3.95 ,  5.71 ,  8.01 ,  3.46 ,  4.41 ,  4.99 ,
#         5.87 ,  6.49 ,  5.98 ,  4.89 ,  7.49 ,  9.95 ,  8.06 ,  7.74 ,
#         7.2  ,  2.28 ,  3.76 ,  7.87 ,  3.98 ,  7.15 ,  2.69 , 12.04 ,
#         9.29 , 30.61 , 19.77 , 10.21 , 15.04 ,  7.27 , 18.54 ,  6.8  ,
#        35.96 , 18.61 ,  7.7  , 36.23 ,  6.95 , 23.15 , 20.45 , 13.74 ,
#        20.91 ,  6.76 , 12.48 ,  8.93 , 14.68 , 12.35 , 22.83 , 14.89 ,
#         7.85 , 25.39 , 13.46 , 23.73 , 92.6  ,  6.05 , 16.09 , 13.7  ,
#        22.78 , 18.64 ,  1.9  ,  1.82 ,  1.78 ,  1.6  ,  1.47 ,  2.37 ,
#         3.45 ,  1.5  ,  2.4  ,  1.4  ,  1.26 ,  1.17 ,  1.75 ,  0.95 ,
#         0.8  ,  0.87 ,  0.84 ,  0.82 ,  0.81 ,  0.74 ,  1.2  ,  0.787,
#         0.99 ,  0.94 ,  0.826,  0.55 ,  0.88 ,  0.51 ,  0.52 ,  0.54 ,
# ...

# %%
 car['Kms_Driven'].unique()
# Out:
# array([ 27000,  43000,   6900,   5200,  42450,   2071,  18796,  33429,
#         20273,  42367,   2135,  51000,  15000,  26000,  77427,  41678,
#         35500,  41442,  25000,   2400,  50000,  45280,  56879,  20000,
#         55138,  16200,  44542,  45000,  51439,  54200,  39000,  49998,
#         48767, 127000,  10079,  62000,  24524,  46706,  58000,  45780,
#         64532,  65000,  25870,  37000, 104707,  40000, 135000,  90000,
#         70000,  40534,  39485,  41000,  40001,  40588,  78000,  47000,
#          6000,  11000,  59000,  88000,  12000,  71000,  56001,  83000,
#         36000,  72000, 135154,  80000,  89000,  23000,  38000, 197176,
#        142000,  56000,  58242,  75000,  29000,   8700,  50024,   3000,
#          1400,   4000,   1200,   4100,  21700,  16500,  18000,   7000,
#         35000,  17000,  17500,  33000,  14000,   5400,   5700,  46500,
#         11500,   1300,   5000,   3500,    500,  11800,  23500,  16000,
# ...

# %%
 car['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# # Checking relationship of Company with Price

# %%
car['company'].unique()
# Out:
# array(['maruti suzuki', 'toyota', 'other', 'bajaj', 'honda', 'yamaha',
#        'tvs', 'hero', 'hyndai'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(figsize=(10,7))
ax=sns.boxplot(x='company',y='Selling_Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# # Checking relationship of Year with Price

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='Year',y='Selling_Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\jeeva\AppData\Local\Temp\ipykernel_1412\2916625616.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %% [markdown]
# # Checking relationship of kms_driven with Price

# %%
sns.relplot(x='Kms_Driven',y='Selling_Price',data=car,height=7,aspect=1.5)

# %% [markdown]
# # Checking relationship of Fuel Type with Price

# %%
plt.subplots(figsize=(10,7))
sns.boxplot(x='Fuel_Type',y='Selling_Price',data=car)
# Out:
# <AxesSubplot: xlabel='Fuel_Type', ylabel='Selling_Price'>

# %% [markdown]
# # Relationship of Price with FuelType, Year and Company mixed

# %%
ax=sns.relplot(x='company',y='Selling_Price',data=car,hue='Fuel_Type',size='Year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# # Extracting Training Data

# %%
X=car[['Car_Name','company','Year','Kms_Driven','Fuel_Type']]
y=car['Selling_Price']

# %%
X
# Out:
#     Car_Name        company  Year  Kms_Driven Fuel_Type
# 0       ritz  maruti suzuki  2014       27000    Petrol
# 1        sx4  maruti suzuki  2013       43000    Diesel
# 2       ciaz  maruti suzuki  2017        6900    Petrol
# 3    wagon r  maruti suzuki  2011        5200    Petrol
# 4      swift  maruti suzuki  2014       42450    Diesel
# ..       ...            ...   ...         ...       ...
# 296     city          honda  2016       33988    Diesel
# 297     brio          honda  2015       60000    Petrol
# 298     city          honda  2009       87934    Petrol
# 299     city          honda  2017        9000    Diesel
# 300     brio          honda  2016        5464    Petrol
#
# [301 rows x 5 columns]

# %% [markdown]
# # Applying Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# # Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['Car_Name','company','Fuel_Type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Car_Name','company','Fuel_Type']),
                                    remainder='passthrough')

# %% [markdown]
# # Linear Regression Model

# %%
lr=LinearRegression()

# %% [markdown]
# # Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# # Fitting the model

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['800', 'Activa 3g', 'Activa 4g', 'Bajaj  ct 100',
#        'Bajaj Avenger 150', 'Bajaj Avenger 150 street',
#        'Bajaj Avenger 220', 'Bajaj Avenger 220 dtsi',
#        'Bajaj Avenger Street 220', 'Bajaj Discover 100',
#        'Bajaj Discover 125', 'Bajaj Dominar 400', 'Baj...
#        'grand i10', 'i10', 'i20', 'ignis', 'innova', 'jazz',
#        'land cruiser', 'omni', 'ritz', 's cross', 'swift', 'sx4', 'verna',
#        'vitara brezza', 'wagon r', 'xcent'], dtype=object),
#                                                                             array(['bajaj', 'hero', 'honda', 'hyndai', 'maruti suzuki', 'other',
#        'toyota', 'tvs', 'yamaha'], dtype=object),
# ...

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# # Checking R2 Score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7215401334806768

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
import numpy as np
np.argmax(scores)
# Out:
# 557

# %%
scores[np.argmax(scores)]
# Out:
# 0.9359321406575599

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['swift','maruti suzuki',2017,100,'Petrol']).reshape(1,5)))
# Out:
# array([3.99323371])

# %%
pipe.predict(pd.DataFrame(columns=['Car_Name','company','Year','Kms_Driven','Fuel_Type'],data=np.array(['swift','maruti suzuki',2017,10000,'Petrol']).reshape(1,5)))
# Out:
# array([3.99221016])
